# %%
import pandas as pd
df=pd.read_csv('dataset/Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total     HP  Attack
# 0      1              Bulbasaur    Grass  Poison    318   45.0    49.0  \
# 1      2                Ivysaur    Grass  Poison    405   60.0    62.0
# 2      3               Venusaur    Grass  Poison    525    NaN    82.0
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   80.0     NaN
# 4      4             Charmander     Fire     NaN    309    NaN    52.0
# ..   ...                    ...      ...     ...    ...    ...     ...
# 795  719                Diancie     Rock   Fairy    600   50.0   100.0
# 796  719    DiancieMega Diancie     Rock   Fairy    700   50.0   160.0
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  180.0     NaN
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   80.0   160.0
# 799  721              Volcanion     Fire   Water    600   80.0   110.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.dropna(inplace=True)

# %%
def myfun(a,b):
    for x,y in zip(a.items(),b.items()):
        vv=(x[1]+y[1])/2
        print(vv)
        if vv>80:
            return 1
        else:
            return 0
    
    
df['Attack'].fillna(myfun(df['HP'],df['Speed']))
# Out:
# 45.0
# 0       49.0
# 6       84.0
# 7      130.0
# 8      104.0
# 15      45.0
#        ...
# 793    131.0
# 794    100.0
# 795    100.0
# 798    160.0
# 799    110.0
# Name: Attack, Length: 409, dtype: float64

# %%
df['HP']
# Out:
# 0       45.0
# 1       60.0
# 2        NaN
# 3       80.0
# 4        NaN
#        ...
# 795     50.0
# 796     50.0
# 797    180.0
# 798     80.0
# 799     80.0
# Name: HP, Length: 800, dtype: float64

# %%
#conditional operator
df[df['HP']>50]
# Out:
#        #                       Name   Type 1  Type 2  Total     HP  Attack
# 1      2                    Ivysaur    Grass  Poison    405   60.0    62.0  \
# 3      3      VenusaurMega Venusaur    Grass  Poison    625   80.0     NaN
# 5      5                 Charmeleon     Fire     NaN    405   58.0    64.0
# 6      6                  Charizard     Fire  Flying    534   78.0    84.0
# 7      6  CharizardMega Charizard X     Fire  Dragon    634   78.0   130.0
# ..   ...                        ...      ...     ...    ...    ...     ...
# 793  717                    Yveltal     Dark  Flying    680  126.0   131.0
# 794  718           Zygarde50% Forme   Dragon  Ground    600  108.0   100.0
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600  180.0     NaN
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680   80.0   160.0
# 799  721                  Volcanion     Fire   Water    600   80.0   110.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[df['HP']>50].Attack
# Out:
# 1       62.0
# 3        NaN
# 5       64.0
# 6       84.0
# 7      130.0
#        ...
# 793    131.0
# 794    100.0
# 797      NaN
# 798    160.0
# 799    110.0
# Name: Attack, Length: 588, dtype: float64

# %%
df[df['HP']>50].Generation
# Out:
# 1      1
# 3      1
# 5      1
# 6      1
# 7      1
#       ..
# 793    6
# 794    6
# 797    6
# 798    6
# 799    6
# Name: Generation, Length: 588, dtype: int64

# %%
df[df['HP']>50][['Name','HP']]
# Out:
#                           Name     HP
# 1                      Ivysaur   60.0
# 3        VenusaurMega Venusaur   80.0
# 5                   Charmeleon   58.0
# 6                    Charizard   78.0
# 7    CharizardMega Charizard X   78.0
# ..                         ...    ...
# 793                    Yveltal  126.0
# 794           Zygarde50% Forme  108.0
# 797        HoopaHoopa Confined  180.0
# 798         HoopaHoopa Unbound   80.0
# 799                  Volcanion   80.0
#
# [588 rows x 2 columns]

# %%
df[(df.Speed==100) & (df.Legendary==True)][['Name','Total','Type 1']]
#Speed 100 Legendary True --> Name Total Type 1
# Out:
#                   Name  Total    Type 1
# 157             Zapdos    580  Electric
# 263              Entei    580      Fire
# 427            Jirachi    600     Steel
# 541             Palkia    680     Water
# 543          Regigigas    670    Normal
# 550  ShayminLand Forme    600     Grass
# 553            Victini    600   Psychic

# %%
#pandas = dataframe
#query
#where 

#numpy npwhere
#np filter

# %%
df[df.Name=='Charizard']
# Out:
#    #       Name Type 1  Type 2  Total    HP  Attack  Defense  Sp. Atk
# 6  6  Charizard   Fire  Flying    534  78.0    84.0     78.0      109  \
#
#    Sp. Def  Speed  Generation  Legendary
# 6       85    100           1      False

# %%
df[df.Name.str.contains('Charizard')]
# Out:
#    #                       Name Type 1  Type 2  Total    HP  Attack  Defense
# 6  6                  Charizard   Fire  Flying    534  78.0    84.0     78.0  \
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78.0   130.0    111.0
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78.0   104.0     78.0
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False

# %%
df[~df.Name.str.contains('Charizard')] #not
# Out:
#        #                   Name   Type 1  Type 2  Total     HP  Attack
# 0      1              Bulbasaur    Grass  Poison    318   45.0    49.0  \
# 1      2                Ivysaur    Grass  Poison    405   60.0    62.0
# 2      3               Venusaur    Grass  Poison    525    NaN    82.0
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   80.0     NaN
# 4      4             Charmander     Fire     NaN    309    NaN    52.0
# ..   ...                    ...      ...     ...    ...    ...     ...
# 795  719                Diancie     Rock   Fairy    600   50.0   100.0
# 796  719    DiancieMega Diancie     Rock   Fairy    700   50.0   160.0
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  180.0     NaN
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   80.0   160.0
# 799  721              Volcanion     Fire   Water    600   80.0   110.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[df.Name!='Charizard']
# Out:
#        #                   Name   Type 1  Type 2  Total     HP  Attack
# 0      1              Bulbasaur    Grass  Poison    318   45.0    49.0  \
# 1      2                Ivysaur    Grass  Poison    405   60.0    62.0
# 2      3               Venusaur    Grass  Poison    525    NaN    82.0
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   80.0     NaN
# 4      4             Charmander     Fire     NaN    309    NaN    52.0
# ..   ...                    ...      ...     ...    ...    ...     ...
# 795  719                Diancie     Rock   Fairy    600   50.0   100.0
# 796  719    DiancieMega Diancie     Rock   Fairy    700   50.0   160.0
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  180.0     NaN
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   80.0   160.0
# 799  721              Volcanion     Fire   Water    600   80.0   110.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[df.Name.str.lower()=='charizard']
# Out:
#    #       Name Type 1  Type 2  Total    HP  Attack  Defense  Sp. Atk
# 6  6  Charizard   Fire  Flying    534  78.0    84.0     78.0      109  \
#
#    Sp. Def  Speed  Generation  Legendary
# 6       85    100           1      False

# %%
df[df.Name.str.upper().str.strip()=='CHARIZARD']
# Out:
#    #       Name Type 1  Type 2  Total    HP  Attack  Defense  Sp. Atk
# 6  6  Charizard   Fire  Flying    534  78.0    84.0     78.0      109  \
#
#    Sp. Def  Speed  Generation  Legendary
# 6       85    100           1      False

# %%
arr_name=['Charizard','Diancie','Volcanion']
type2_name=['Flying','Water','Fairy']
df[(df.Name.isin(arr_name)) & (df['Type 2'].isin(type2_name))]
# Out:
#        #       Name Type 1  Type 2  Total    HP  Attack  Defense  Sp. Atk
# 6      6  Charizard   Fire  Flying    534  78.0    84.0     78.0      109  \
# 795  719    Diancie   Rock   Fairy    600  50.0   100.0    150.0      100
# 799  721  Volcanion   Fire   Water    600  80.0   110.0    120.0      130
#
#      Sp. Def  Speed  Generation  Legendary
# 6         85    100           1      False
# 795      150     50           6       True
# 799       90     70           6       True

# %%
df[(df.Name.isin(arr_name)) | (df['Type 2'].isin(type2_name))]
# Out:
#        #                       Name  Type 1  Type 2  Total     HP  Attack
# 6      6                  Charizard    Fire  Flying    534   78.0    84.0  \
# 8      6  CharizardMega Charizard Y    Fire  Flying    634   78.0   104.0
# 15    12                 Butterfree     Bug  Flying    395   60.0    45.0
# 20    16                     Pidgey  Normal  Flying    251   40.0    45.0
# 21    17                  Pidgeotto  Normal  Flying    349   63.0    60.0
# ..   ...                        ...     ...     ...    ...    ...     ...
# 777  707                     Klefki   Steel   Fairy    470   57.0    80.0
# 793  717                    Yveltal    Dark  Flying    680  126.0   131.0
# 795  719                    Diancie    Rock   Fairy    600   50.0   100.0
# 796  719        DiancieMega Diancie    Rock   Fairy    700   50.0   160.0
# 799  721                  Volcanion    Fire   Water    600   80.0   110.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[~(df.Name.isin(arr_name)) & (df['Type 2'].isin(type2_name))]
# Out:
#        #                       Name    Type 1  Type 2  Total     HP  Attack
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78.0   104.0  \
# 15    12                 Butterfree       Bug  Flying    395   60.0    45.0
# 20    16                     Pidgey    Normal  Flying    251   40.0    45.0
# 21    17                  Pidgeotto    Normal  Flying    349   63.0    60.0
# 22    18                    Pidgeot    Normal  Flying    479   83.0    80.0
# ..   ...                        ...       ...     ...    ...    ...     ...
# 772  702                    Dedenne  Electric   Fairy    431   67.0    58.0
# 773  703                    Carbink      Rock   Fairy    500   50.0    50.0
# 777  707                     Klefki     Steel   Fairy    470   57.0    80.0
# 793  717                    Yveltal      Dark  Flying    680  126.0   131.0
# 796  719        DiancieMega Diancie      Rock   Fairy    700   50.0   160.0
#
# ...

# %%
#df.query
df.query("Name=='Yveltal'")
# Out:
#        #     Name Type 1  Type 2  Total     HP  Attack  Defense  Sp. Atk
# 793  717  Yveltal   Dark  Flying    680  126.0   131.0     95.0      131  \
#
#      Sp. Def  Speed  Generation  Legendary
# 793       98     99           6       True

# %%
df.query("HP>100 and Speed<50 or Attack==100")

#Geneation 3 Total 300
# Out:
#        #                   Name    Type 1    Type 2  Total     HP  Attack
# 33    28              Sandslash    Ground       NaN    450   75.0   100.0  \
# 44    39             Jigglypuff    Normal     Fairy    270  115.0    45.0
# 45    40             Wigglytuff    Normal     Fairy    435  140.0    70.0
# 73    67                Machoke  Fighting       NaN    405   80.0   100.0
# 84    78               Rapidash      Fire       NaN    500   65.0   100.0
# 120  112                 Rhydon    Ground      Rock    485  105.0   130.0
# 138  128                 Tauros    Normal       NaN    490   75.0   100.0
# 155  143                Snorlax    Normal       NaN    540  160.0   110.0
# 158  146                Moltres      Fire    Flying    580   90.0   100.0
# 165  151                    Mew   Psychic       NaN    600  100.0   100.0
# 200  185              Sudowoodo      Rock       NaN    410   70.0   100.0
# 217  202              Wobbuffet   Psychic       NaN    405  190.0    33.0
# ...

# %%
#Transformation
#replace without condition
#where 
df['Name']=df['Name'].replace('Diancie','Aung Aung')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total     HP  Attack
# 0      1              Bulbasaur    Grass  Poison    318   45.0    49.0  \
# 1      2                Ivysaur    Grass  Poison    405   60.0    62.0
# 2      3               Venusaur    Grass  Poison    525    NaN    82.0
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   80.0     NaN
# 4      4             Charmander     Fire     NaN    309    NaN    52.0
# ..   ...                    ...      ...     ...    ...    ...     ...
# 795  719              Aung Aung     Rock   Fairy    600   50.0   100.0
# 796  719    DiancieMega Diancie     Rock   Fairy    700   50.0   160.0
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  180.0     NaN
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   80.0   160.0
# 799  721              Volcanion     Fire   Water    600   80.0   110.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[df.Name=='Aung Aung']
# Out:
#        #       Name Type 1 Type 2  Total    HP  Attack  Defense  Sp. Atk
# 795  719  Aung Aung   Rock  Fairy    600  50.0   100.0    150.0      100  \
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True

# %%
#Without condition
import numpy as np
df['new_legend']=np.where(df['Legendary']==True,0,1)
df
# Out:
#        #                   Name   Type 1  Type 2  Total     HP  Attack
# 0      1              Bulbasaur    Grass  Poison    318   45.0    49.0  \
# 1      2                Ivysaur    Grass  Poison    405   60.0    62.0
# 2      3               Venusaur    Grass  Poison    525    NaN    82.0
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   80.0     NaN
# 4      4             Charmander     Fire     NaN    309    NaN    52.0
# ..   ...                    ...      ...     ...    ...    ...     ...
# 795  719              Aung Aung     Rock   Fairy    600   50.0   100.0
# 796  719    DiancieMega Diancie     Rock   Fairy    700   50.0   160.0
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  180.0     NaN
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   80.0   160.0
# 799  721              Volcanion     Fire   Water    600   80.0   110.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  new_legend
# ...

# %%
# !pip install numpy

# %%
df[]
# Out:
#        #                   Name   Type 1  Type 2  Total     HP  Attack
# 0      1              Bulbasaur    Grass  Poison    318   45.0    49.0  \
# 1      2                Ivysaur    Grass  Poison    405   60.0    62.0
# 2      3               Venusaur    Grass  Poison    525    NaN    82.0
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   80.0     NaN
# 4      4             Charmander     Fire     NaN    309    NaN    52.0
# ..   ...                    ...      ...     ...    ...    ...     ...
# 795  719              Aung Aung     Rock   Fairy    600   50.0   100.0
# 796  719    DiancieMega Diancie     Rock   Fairy    700   50.0   160.0
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  180.0     NaN
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   80.0   160.0
# 799  721              Volcanion     Fire   Water    600   80.0   110.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  new_legend
# ...

# %%
df['new_legend']=np.where(df['Legendary']==True,1000,df['Legendary'])

# %%
df['new_legend']=np.where(df['Generation']>3,-999,df['Generation'])
df
# Out:
#        #                   Name   Type 1  Type 2  Total     HP  Attack
# 0      1              Bulbasaur    Grass  Poison    318   45.0    49.0  \
# 1      2                Ivysaur    Grass  Poison    405   60.0    62.0
# 2      3               Venusaur    Grass  Poison    525    NaN    82.0
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   80.0     NaN
# 4      4             Charmander     Fire     NaN    309    NaN    52.0
# ..   ...                    ...      ...     ...    ...    ...     ...
# 795  719              Aung Aung     Rock   Fairy    600   50.0   100.0
# 796  719    DiancieMega Diancie     Rock   Fairy    700   50.0   160.0
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  180.0     NaN
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   80.0   160.0
# 799  721              Volcanion     Fire   Water    600   80.0   110.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  new_legend
# ...

# %%
df.new_legend.value_counts()
# Out:
# new_legend
#  0      403
# -999    368
#  1       29
# Name: count, dtype: int64

# %%
df.loc[df.Speed>100,'newcol']=-9999

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total     HP  Attack
# 0      1              Bulbasaur    Grass  Poison    318   45.0    49.0  \
# 1      2                Ivysaur    Grass  Poison    405   60.0    62.0
# 2      3               Venusaur    Grass  Poison    525    NaN    82.0
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   80.0     NaN
# 4      4             Charmander     Fire     NaN    309    NaN    52.0
# ..   ...                    ...      ...     ...    ...    ...     ...
# 795  719              Aung Aung     Rock   Fairy    600   50.0   100.0
# 796  719    DiancieMega Diancie     Rock   Fairy    700   50.0   160.0
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  180.0     NaN
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   80.0   160.0
# 799  721              Volcanion     Fire   Water    600   80.0   110.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  new_legend
# ...

# %%
#mask
df['HP'].mask(df['Total']>400,1500,inplace=True)

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total      HP  Attack
# 0      1              Bulbasaur    Grass  Poison    318    45.0    49.0  \
# 1      2                Ivysaur    Grass  Poison    405  1500.0    62.0
# 2      3               Venusaur    Grass  Poison    525  1500.0    82.0
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  1500.0     NaN
# 4      4             Charmander     Fire     NaN    309     NaN    52.0
# ..   ...                    ...      ...     ...    ...     ...     ...
# 795  719              Aung Aung     Rock   Fairy    600  1500.0   100.0
# 796  719    DiancieMega Diancie     Rock   Fairy    700  1500.0   160.0
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  1500.0     NaN
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  1500.0   160.0
# 799  721              Volcanion     Fire   Water    600  1500.0   110.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  new_legend
# ...

# %%
df['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
#Aggreation - pivot table  - groupby
df.groupby('Type 1')['HP'].mean()
# Out:
# Type 1
# Bug          679.405797
# Dark        1031.645161
# Dragon      1272.968750
# Electric    1069.522727
# Fairy        820.764706
# Fighting    1017.555556
# Fire        1102.254902
# Flying      1135.000000
# Ghost        955.656250
# Grass        920.214286
# Ground       912.875000
# Ice          956.541667
# Normal       837.928571
# Poison       776.714286
# Psychic     1016.877193
# Rock         939.431818
# Steel       1177.111111
# Water        930.758929
# Name: HP, dtype: float64

# %%
df.groupby('Type 1')[['Speed','HP']].mean()
# Out:
#                Speed           HP
# Type 1
# Bug        61.681159   679.405797
# Dark       76.161290  1031.645161
# Dragon     83.031250  1272.968750
# Electric   84.500000  1069.522727
# Fairy      48.588235   820.764706
# Fighting   66.074074  1017.555556
# Fire       74.442308  1102.254902
# Flying    102.500000  1135.000000
# Ghost      64.343750   955.656250
# Grass      61.928571   920.214286
# Ground     63.906250   912.875000
# Ice        63.458333   956.541667
# Normal     71.551020   837.928571
# Poison     63.571429   776.714286
# Psychic    81.491228  1016.877193
# Rock       55.909091   939.431818
# Steel      55.259259  1177.111111
# Water      65.964286   930.758929

# %%
df.groupby('Type 2')[['Defense','Attack']].mean().sort_values(by='Attack')
# Out:
#              Defense      Attack
# Type 2
# Normal     53.750000   52.750000
# Fairy      72.227273   61.608696
# Poison     59.454545   66.606061
# Water      85.071429   70.142857
# Electric   68.333333   72.666667
# Grass      80.120000   74.160000
# Psychic    87.030303   74.696970
# Flying     68.309278   80.288660
# Fire       80.166667   81.250000
# Ghost      89.428571   82.153846
# Rock      126.857143   84.000000
# Ground     90.314286   89.857143
# Bug        80.000000   90.000000
# Steel     104.636364   92.590909
# Dragon     87.055556   94.444444
# Ice        85.642857   98.000000
# Dark       72.050000  109.800000
# Fighting   82.500000  112.846154

# %%
df.groupby('Type 2')['Defense'].mean().sort_values(ascending=False)
# Out:
# Type 2
# Rock        126.857143
# Steel       104.636364
# Ground       90.314286
# Ghost        89.428571
# Dragon       87.055556
# Psychic      87.030303
# Ice          85.642857
# Water        85.071429
# Fighting     82.500000
# Fire         80.166667
# Grass        80.120000
# Bug          80.000000
# Fairy        72.227273
# Dark         72.050000
# Electric     68.333333
# Flying       68.309278
# Poison       59.454545
# Normal       53.750000
# Name: Defense, dtype: float64

# %%
df.groupby(['Type 1','Type 2'])[['HP','Speed']].mean()
# Out:
#                           HP      Speed
# Type 1 Type 2
# Bug    Electric   775.000000  86.500000
#        Fighting  1500.000000  80.000000
#        Fire       777.500000  80.000000
#        Flying     879.285714  82.857143
#        Ghost        1.000000  40.000000
# ...                      ...        ...
# Water  Ice       1500.000000  66.666667
#        Poison    1013.333333  85.000000
#        Psychic   1218.000000  44.000000
#        Rock       777.250000  36.000000
#        Steel     1500.000000  60.000000
#
# [136 rows x 2 columns]

# %%
df.groupby(['Type 1','Type 2'])[['HP','Speed']].mean().sort_values(by='HP')
# Out:
#                      HP       Speed
# Type 1 Type 2
# Bug    Ghost        1.0   40.000000
# Poison Bug         40.0   65.000000
# Bug    Water       40.0   65.000000
# Poison Water       50.0   30.000000
# Bug    Poison     412.5   65.916667
# ...                 ...         ...
# Grass  Ground    1500.0   56.000000
#        Fighting  1500.0   80.666667
#        Dragon    1500.0  145.000000
# Poison Ground    1500.0   80.500000
# Water  Steel     1500.0   60.000000
#
# [136 rows x 2 columns]

# %%
#groupby with condition
df[df['Type 2']=='Water'].groupby(['Type 1'])[['HP','Speed']].mean()
# Out:
#                    HP      Speed
# Type 1
# Bug         40.000000  65.000000
# Electric  1500.000000  86.000000
# Fire      1500.000000  70.000000
# Ice       1023.333333  45.000000
# Normal    1500.000000  71.000000
# Poison      50.000000  30.000000
# Rock       767.833333  57.166667

# %%
sales=pd.read_csv('dataset/supermarket_sales.csv')
sales
# Out:
#       Invoice ID Branch       City Customer type  Gender
# 0    750-67-8428      A     Yangon        Member  Female  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total
# 0         Health and beauty       74.69         7  26.1415   548.9715  \
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
sales.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
sales.Branch.value_counts()
# Out:
# Branch
# A    340
# B    332
# C    328
# Name: count, dtype: int64

# %%
sales.groupby('Branch')['gross income'].sum()
# Out:
# Branch
# A    5057.1605
# B    5057.0320
# C    5265.1765
# Name: gross income, dtype: float64

# %%
sales.groupby('Branch')['gross income'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Branch'>

# %%
sales[sales.City=='Yangon'].groupby(['Product line'])['Quantity'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Product line'>

# %%
sales.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sales.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
sales.City.value_counts()
# Out:
# City
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: count, dtype: int64

# %%
sales[sales.City=='Naypyitaw'].groupby(['Product line'])['Rating'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Product line'>

# %%
sales.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender
# 0  750-67-8428      A     Yangon        Member  Female  \
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019  \
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  3/3/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4

# %%
sales.groupby('Customer type')['Total'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Customer type'>

# %%
sales[sales['Product line']=='Electronic accessories'].groupby(['City'])['Total'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
sales.groupby(['City','Payment'])['Rating'].count()
# Out:
# City       Payment
# Mandalay   Cash           110
#            Credit card    109
#            Ewallet        113
# Naypyitaw  Cash           124
#            Credit card     98
#            Ewallet        106
# Yangon     Cash           110
#            Credit card    104
#            Ewallet        126
# Name: Rating, dtype: int64

# %%
sales.groupby(['City','Payment'])['Rating'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='City,Payment'>

# %%
#groupby + filter
city=sales.groupby('City')
city.filter(lambda x:x['gross income'].sum()>5200)
# Out:
#       Invoice ID Branch       City Customer type  Gender
# 1    226-31-3081      C  Naypyitaw        Normal  Female  \
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 20   300-71-4605      C  Naypyitaw        Member    Male
# 34   183-56-6882      C  Naypyitaw        Member  Female
# ..           ...    ...        ...           ...     ...
# 983  148-41-7930      C  Naypyitaw        Normal    Male
# 984  189-40-5216      C  Naypyitaw        Normal    Male
# 988  267-62-7380      C  Naypyitaw        Member    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total
# 1    Electronic accessories       15.28         5   3.8200   80.2200  \
# 5    Electronic accessories       85.39         7  29.8865  627.6165
# 7        Home and lifestyle       73.56        10  36.7800  772.3800
# ...

# %%
sales.groupby('City')['gross income'].sum()
# Out:
# City
# Mandalay     5057.0320
# Naypyitaw    5265.1765
# Yangon       5057.1605
# Name: gross income, dtype: float64

# %%
#group + agg
sales.groupby(['City','Payment']).agg(['min','max','count'])
# Out:
#                         Invoice ID                    Branch
#                                min          max count    min max count
# City      Payment
# Mandalay  Cash         110-48-7033  895-03-6665   110      B   B   110  \
#           Credit card  109-86-4363  889-04-9723   109      B   B   109
#           Ewallet      109-28-2512  895-66-0685   113      B   B   113
# Naypyitaw Cash         102-06-2002  885-56-0389   124      C   C   124
#           Credit card  102-77-2261  894-41-5205    98      C   C    98
#           Ewallet      101-81-4070  886-77-9084   106      C   C   106
# Yangon    Cash         106-35-6779  896-34-0956   110      A   A   110
#           Credit card  101-17-6199  886-18-2897   104      A   A   104
#           Ewallet      105-10-6182  898-04-2717   126      A   A   126
#
#                       Customer type                Gender  ...  cogs
#                                 min     max count     min  ... count
# ...

# %%
#File Merging
#Same file formats -- same column, same column count
#differnt file format

april=pd.read_csv('dataset/Sales_Data/Sales_April_2019.csv')
august=pd.read_csv('dataset/Sales_Data/Sales_August_2019.csv')
print(len(april))
print(len(august))
# Out:
# 18383
# 12011

# %%
two_df=pd.concat([april,august,october,....])
two_df
# Out:
#       Order ID                     Product Quantity Ordered Price Each
# 0       176558        USB-C Charging Cable                2      11.95  \
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 12006   248146  Bose SoundSport Headphones                1      99.99
# 12007   248147      AAA Batteries (4-pack)                3       2.99
# 12008   248148       AA Batteries (4-pack)                1       3.84
# 12009   248149        USB-C Charging Cable                1      11.95
# 12010   248150       AA Batteries (4-pack)                1       3.84
#
#            Order Date                         Purchase Address
# ...

# %%
import os
files=os.listdir('dataset/Sales_Data')
all_df=pd.DataFrame()

# %%
all_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
files
# Out:
# ['Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %%
#april=pd.read_csv('dataset/Sales_Data/Sales_April_2019.csv')
for f in files:
    onedf=pd.read_csv('dataset/Sales_Data/'+f)
    all_df=pd.concat([all_df,onedf])
all_df
# Out:
#       Order ID                     Product Quantity Ordered Price Each
# 0       176558        USB-C Charging Cable                2      11.95  \
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %%
all_df.dropna(inplace=True)

# %%
all_df.to_csv('dataset/Sales_Data/Alldf.csv')

# %%
all_df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
all_df.head(3)
# Out:
#   Order ID                     Product Quantity Ordered Price Each
# 0   176558        USB-C Charging Cable                2      11.95  \
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
all_df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object
